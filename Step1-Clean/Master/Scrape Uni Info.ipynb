# %%
# Imports
import pandas as pd
import numpy as np
from splinter import Browser
from bs4 import BeautifulSoup
import requests

# %%
wiki_url = "https://www.wikipedia.org/wiki/"
goog_url = "https://www.google.com/"

# %%
# !which chromedriver
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
# browser.visit(wiki_url)

# %%
# import data
uni_data = pd.read_csv("API_SQL_UNITID-NAME.csv")
uni_data.head(2)
# Out:
#    UNITID                               INSTNM
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham

# %%
inst = uni_data['INSTNM'][860]
inst = inst.replace(" ", "_")
inst_url = goog_url + inst
# inst_url
wiki_response = requests.get(inst_url)
wiki_soup = BeautifulSoup(wiki_response.text, 'html.parser')
# inst

# %%
inst_url
# Out:
# 'https://www.google.com/Princeton_University'

# %%
# Snippet
wiki_soup.find_all('p')
# Out:
# [<p class="mw-empty-elt">
#  </p>,
# ...

# %%
# https://en.wikipedia.org/wiki/University_of_Alabama"#/media/"File:University_of_Alabama_seal.svg

# %%
inst_facts = pd.read_html(inst_url)
inst_facts = inst_facts[0]
inst_facts = inst_facts.set_index(0)
# inst_facts

# motto = inst_facts.loc['Motto'][1]
type_of_uni = inst_facts.loc['Type'][1]
# year_est = inst_facts.loc['Established'][1]
# students = inst_facts.loc['Students'][1][:-3]
# nickname = inst_facts.loc['Nickname'][1]
# campus = inst_facts.loc['Campus'][1]
type_of_uni
# Out:
# 'Public, HBCULand-grant universitySpace-grant'

# %%
href = wiki_soup.find_all('a')[4]['href']
add = "#/media/"
img_link = inst_url + add + href
img_link
# Out:
# 'https://www.wikipedia.org/wiki/Princeton_University#/media/#p-search'

# %%
# Out:
# '#/media/'

# %%
# # university image url
# href = wiki_soup.find_all('a')[4]['hre
# # wiki_addon = 'https://en.wikipedia.org'
# # wiki_img_response = requests.get(wiki_addon + href)
# # wiki_img_soup = BeautifulSoup(wiki_img_response.text, 'html.parser')
# # new_href = wiki_img_soup.find_all('a')[6]['href']
# # http = 'https:'
# # uni_img_url = http + new_href
# # uni_img_url
# href

# %%
img_link = inst_url + add + href
img_link
# Out:
# 'https://www.wikipedia.org/wiki/Flagler_College-St_Augustine#/media//wiki/File:Wiktionary-logo-v2.svg'

# %%
href = wiki_soup.find_all('a')
href
# Out:
# [<a id="top"></a>,
#  <a class="mw-redirect" href="/w/index.php?title=The_University_of_Alabama&amp;redirect=no" title="The University of Alabama">The University of Alabama</a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a class="mw-disambig" href="/wiki/University_of_Alabama_(disambiguation)" title="University of Alabama (disambiguation)">University of Alabama (disambiguation)</a>,
# ...

# %%
wiki_soup.find_all('a')
src = wiki_soup.find_all('img')[1]['src']
http = 'https:'
uni_img_url = http + src
uni_img_url
# Out:
# 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikibooks-logo.svg/30px-Wikibooks-logo.svg.png'

# %%
inst_list = list(uni_data['INSTNM'])

# %%
snippet_list = []
motto_list = []
type_list = []
year_est_list = []
students_list = []
nickname_list = []
campus_list = []

for sch in inst_list:
    try:
    #     instname
        inst = sch
        inst = inst.replace(" ", "_")
        inst_url = wiki_url + inst
        wiki_response = requests.get(inst_url)
        wiki_soup = BeautifulSoup(wiki_response.text, 'html.parser')
    #     # Snippet
        snippet = wiki_soup.find_all('p')[0].text

#         print(snippet)  
    #     institution facts
        inst_facts = pd.read_html(inst_url)
        inst_facts = inst_facts[0]
        inst_facts = inst_facts.set_index(0)


        motto = inst_facts.loc['Motto'][1]
        type_of_uni = inst_facts.loc['Type'][1]
        year_est = inst_facts.loc['Established'][1]
        students = inst_facts.loc['Students'][1][:-3]
        nickname = inst_facts.loc['Nickname'][1]
        campus = inst_facts.loc['Campus'][1]

        
    except:
        pass
    
        snippet_list.append(snippet)
        motto_list.append(motto)
        type_list.append(type_of_uni)
        year_est_list.append(year_est)
        students_list.append(students)
        nickname_list.append(nickname)
        campus_list.append(campus)

# %%
snippet_list

# %%
type_list = []

# %%
for index, row in uni_data.iterrows():
    unitid = row['UNITID']
    inst = row['INSTNM']
    inst = inst.replace(" ", "_")
    inst_url = wiki_url + inst
    
    wiki_response = requests.get(inst_url)
    wiki_soup = BeautifulSoup(wiki_response.text, 'html.parser')
    

    
    try:
        inst_facts = pd.read_html(inst_url)
        inst_facts = inst_facts[0]
        inst_facts = inst_facts.set_index(0)
            #     # Snippet
        type_of_uni = inst_facts.loc['Type'][1]
        
    except:
        
        type_of_uni = "NA"
        
    type_list.append(type_of_uni)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-20-536807851ca9> in <module>
#      11
#      12     try:
# ---> 13         inst_facts = pd.read_html(inst_url)
#      14         inst_facts = inst_facts[0]
#      15         inst_facts = inst_facts.set_index(0)
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1092                   decimal=decimal, converters=converters, na_values=na_values,
#    1093                   keep_default_na=keep_default_na,
# -> 1094                   displayed_only=displayed_only)
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     914             break
# ...

# %%
for index, row in uni_data.iterrows():
    unitid = row['UNITID']
    inst = row['INSTNM']
    inst = inst.replace(" ", "_")
    inst_url = wiki_url + inst
    
    wiki_response = requests.get(inst_url)
    wiki_soup = BeautifulSoup(wiki_response.text, 'html.parser')
    

    inst_facts = pd.read_html(inst_url)
    inst_facts = inst_facts[0]
    inst_facts = inst_facts.set_index(0)

    try:
        stu = inst_facts.loc['Students'][1]
    except:
        stu = 'N/A'
    print(index)
    print(stu)
# Out:
# 0
# 6,001 (Fall 2018)[1]
# 1
# 21923
# 2
# N/A
# 3
# 9736
# 4
# 5475
# 5
# 38,563[4]
# 6
# 3500
# 7
# 5,211 (Fall 2018)[3]
# 8
# 30,440 (Fall 2018)[5]
# 9
# N/A
# 10
# 445 (2017–18)[1]
# 11
# 3574
# 12
# 1107
# 13
# N/A
# 14
# N/A
# 15
# N/A
# 16
# 5157
# 17
# 1500
# 18
# Approx. 1,600
# 19
# 2600
# 20
# 7650
# 21
# N/A
# 22
# 5,619 (Fall 2018)[2]
# 23
# 600
# 24
# 14834
# 25
# 1439
# 26
# N/A
# 27
# 615 (Fall 2018)
# 28
# 2500
# 29
# N/A
# 30
# 3,140 (2017)[2]
# 31
# N/A
# 32
# 17,962 (14,308 on the Anchorage campus and 3,000+ enrolled in the community campuses [1]
# 33
# 51 [1]
# 34
# 8336
# 35
# N/A
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-40-d01cb950fb67> in <module>
#       9
#      10
# ---> 11     inst_facts = pd.read_html(inst_url)
#      12     inst_facts = inst_facts[0]
#      13     inst_facts = inst_facts.set_index(0)
#
# ...

# %%
stu_list = []

# %%
for index, row in uni_data.iterrows():
    unitid = row['UNITID']
    inst = row['INSTNM']
    inst = inst.replace(" ", "_")
    inst_url = wiki_url + inst
    
    wiki_response = requests.get(inst_url)
    wiki_soup = BeautifulSoup(wiki_response.text, 'html.parser')
    

    inst_facts = pd.read_html(inst_url)
    inst_facts = inst_facts[0]
    inst_facts = inst_facts.set_index(0)

    try:
        stu = inst_facts.loc['Students'][1]
    except:
        stu = 'N/A'
    print(index)
    print(stu)
    
    stu_list.append(stu)
# Out:
# 0
# 6,001 (Fall 2018)[1]
# 1
# 21923
# 2
# N/A
# 3
# 9736
# 4
# 5475
# 5
# 38,563[4]
# 6
# 3500
# 7
# 5,211 (Fall 2018)[3]
# 8
# 30,440 (Fall 2018)[5]
# 9
# N/A
# 10
# 445 (2017–18)[1]
# 11
# 3574
# 12
# 1107
# 13
# N/A
# 14
# N/A
# 15
# N/A
# 16
# 5157
# 17
# 1500
# 18
# Approx. 1,600
# 19
# 2600
# 20
# 7650
# 21
# N/A
# 22
# 5,619 (Fall 2018)[2]
# 23
# 600
# 24
# 14834
# 25
# 1439
# 26
# N/A
# 27
# 615 (Fall 2018)
# 28
# 2500
# 29
# N/A
# 30
# 3,140 (2017)[2]
# 31
# N/A
# 32
# 17,962 (14,308 on the Anchorage campus and 3,000+ enrolled in the community campuses [1]
# 33
# 51 [1]
# 34
# 8336
# 35
# N/A
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-50-ceb7254c785e> in <module>
#       9
#      10
# ---> 11     inst_facts = pd.read_html(inst_url)
#      12     inst_facts = inst_facts[0]
#      13     inst_facts = inst_facts.set_index(0)
#
# ...
